# %%
import zipfile

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('drive/MyDrive/DL final project') # add shortcut to the DL final project to your google drive
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-491eba6b8929> in <cell line: 2>()
#       1 import os
# ----> 2 os.chdir('drive/MyDrive/DL final project') # add shortcut to the DL final project to your google drive
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/MyDrive/DL final project'

# %%
zip_ref = zipfile.ZipFile("prep_data.zip", 'r')
zip_ref.extractall("")
zip_ref.close()

# %%
# import shutil
# shutil.rmtree('prep_data')

# %%
import pandas as pd

# %%
os.listdir()
# Out:
# ['final_emotion.ipynb',
#  'multimodal_nn.jpg',
#  'raw_data',
#  'preprocessing.ipynb',
#  'readme.gdoc',
#  'prep_data.zip',
#  'unzip.ipynb',
#  'prep_data']

# %%
pd.read_csv('prep_data/epochs/0/0_dog 7_4_6.csv')
# Out:
#      Unnamed: 0  TIME(2022/07/06 12:39:07.507)    FPOGX    FPOGY  FPOGID  \
# 0          7573                      122.76831  0.45358  0.50776     224
# 1          7574                      122.78442  0.45338  0.50856     224
# 2          7575                      122.80078  0.45327  0.50885     224
# 3          7576                      122.81714  0.45316  0.50887     224
# 4          7577                      122.83325  0.45273  0.50853     224
# ..          ...                            ...      ...      ...     ...
# 296        7869                      127.60474  0.09939  0.56685     232
# 297        7870                      127.62061  0.08465  0.54435     232
# 298        7871                      127.63672  0.07976  0.55757     232
# 299        7872                      127.65308  0.08623  0.56243     233
# 300        7873                      127.66919  0.09130  0.56786     233
#
#      FPOGV     LPMM  LPMMV     RPMM  RPMMV     GSR  GSRV  HR  HRV  \
# 0        1  1.67199      0  3.89673      1  262256     1  85    1
# 1        1  1.67199      0  3.61032      1  261980     1  85    1
# 2        1  1.67199      0  3.69905      1  258110     1  85    1
# 3        1  1.67199      0  3.61293      1  262033     1  85    1
# 4        1  1.67199      0  2.91322      1  259693     1  85    1
# ..     ...      ...    ...      ...    ...     ...   ...  ..  ...
# 296      0  2.21087      0  3.09987      1  239326     1  83    1
# 297      0  2.21087      0  3.29431      1  241096     1  83    1
# 298      0  2.21087      0  3.15171      1  242866     1  83    1
# 299      1  2.21087      0  3.13252      1  239063     1  83    1
# 300      1  2.21087      0  3.35212      1  243676     1  83    1
#
#                 Image  Arousal  Valence
# 0    Images/dog 7.jpg        4        6
# 1    Images/dog 7.jpg        4        6
# 2    Images/dog 7.jpg        4        6
# 3    Images/dog 7.jpg        4        6
# 4    Images/dog 7.jpg        4        6
# ..                ...      ...      ...
# 296  Images/dog 7.jpg        4        6
# 297  Images/dog 7.jpg        4        6
# 298  Images/dog 7.jpg        4        6
# 299  Images/dog 7.jpg        4        6
# 300  Images/dog 7.jpg        4        6
#
# [301 rows x 17 columns]
